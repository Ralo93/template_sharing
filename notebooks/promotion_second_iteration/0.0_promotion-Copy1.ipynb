# %%
import pandas as pd
import os
import numpy as np
import sys
sys.path.append('..')

# %%
data = pd.read_csv(r'../data/raw/promotion/train.csv', delimiter=',')

# %%
data.columns
# Out:
# Index(['EmployeeNo', 'Division', 'Qualification', 'Gender',
#        'Channel_of_Recruitment', 'Trainings_Attended', 'Year_of_birth',
#        'Last_performance_score', 'Year_of_recruitment', 'Targets_met',
#        'Previous_Award', 'Training_score_average', 'State_Of_Origin',
#        'Foreign_schooled', 'Marital_Status', 'Past_Disciplinary_Action',
#        'Previous_IntraDepartmental_Movement', 'No_of_previous_employers',
#        'Promoted_or_Not'],
#       dtype='object')

# %%
data.shape
# Out:
# (38312, 19)

# %%
data.head()
# Out:
#     EmployeeNo                               Division        Qualification  \
# 0  YAK/S/00001         Commercial Sales and Marketing     MSc, MBA and PhD
# 1  YAK/S/00002  Customer Support and Field Operations  First Degree or HND
# 2  YAK/S/00003         Commercial Sales and Marketing  First Degree or HND
# 3  YAK/S/00004         Commercial Sales and Marketing  First Degree or HND
# 4  YAK/S/00006               Information and Strategy  First Degree or HND
#
#    Gender   Channel_of_Recruitment  Trainings_Attended  Year_of_birth  \
# 0  Female  Direct Internal process                   2           1986
# 1    Male        Agency and others                   2           1991
# 2    Male  Direct Internal process                   2           1987
# 3    Male        Agency and others                   3           1982
# 4    Male  Direct Internal process                   3           1990
#
#    Last_performance_score  Year_of_recruitment  Targets_met  Previous_Award  \
# 0                    12.5                 2011            1               0
# 1                    12.5                 2015            0               0
# 2                     7.5                 2012            0               0
# 3                     2.5                 2009            0               0
# 4                     7.5                 2012            0               0
#
#    Training_score_average State_Of_Origin Foreign_schooled Marital_Status  \
# 0                      41         ANAMBRA               No        Married
# 1                      52         ANAMBRA              Yes        Married
# 2                      42         KATSINA              Yes        Married
# 3                      42           NIGER              Yes         Single
# 4                      77       AKWA IBOM              Yes        Married
#
#   Past_Disciplinary_Action Previous_IntraDepartmental_Movement  \
# 0                       No                                  No
# 1                       No                                  No
# 2                       No                                  No
# 3                       No                                  No
# 4                       No                                  No
#
#   No_of_previous_employers  Promoted_or_Not
# 0                        0                0
# 1                        0                0
# 2                        0                0
# 3                        1                0
# 4                        1                0

# %%
data.describe()
# Out:
#        Trainings_Attended  Year_of_birth  Last_performance_score  \
# count        38312.000000   38312.000000            38312.000000
# mean             2.253680    1986.209334                7.698959
# std              0.609443       7.646047                3.744135
# min              2.000000    1950.000000                0.000000
# 25%              2.000000    1982.000000                5.000000
# 50%              2.000000    1988.000000                7.500000
# 75%              2.000000    1992.000000               10.000000
# max             11.000000    2001.000000               12.500000
#
#        Year_of_recruitment   Targets_met  Previous_Award  \
# count         38312.000000  38312.000000    38312.000000
# mean           2013.139695      0.352996        0.023152
# std               4.261451      0.477908        0.150388
# min            1982.000000      0.000000        0.000000
# 25%            2012.000000      0.000000        0.000000
# 50%            2014.000000      0.000000        0.000000
# 75%            2016.000000      1.000000        0.000000
# max            2018.000000      1.000000        1.000000
#
#        Training_score_average  Promoted_or_Not
# count            38312.000000     38312.000000
# mean                55.366465         0.084595
# std                 13.362741         0.278282
# min                 31.000000         0.000000
# 25%                 43.000000         0.000000
# 50%                 52.000000         0.000000
# 75%                 68.000000         0.000000
# max                 91.000000         1.000000

# %%
print(os.getcwd())
# Out:
# C:\Users\Administrator\Desktop\raphi_other\repositories\template_project\src

# %%
os.chdir(r'C:\Users\Administrator\Desktop\raphi_other\repositories\template_project\src')

# %%
from eda_first import summarize_dataframe
summarize_dataframe(data)
# Out:
#                                  Column Data Type  Unique Values  \
# 0                            EmployeeNo    object          38312
# 1                              Division    object              9
# 2                         Qualification    object              3
# 3                                Gender    object              2
# 4                Channel_of_Recruitment    object              3
# 5                    Trainings_Attended     int64             10
# 6                         Year_of_birth     int64             49
# 7                Last_performance_score   float64              6
# 8                   Year_of_recruitment     int64             35
# 9                           Targets_met     int64              2
# 10                       Previous_Award     int64              2
# 11               Training_score_average     int64             61
# 12                      State_Of_Origin    object             37
# 13                     Foreign_schooled    object              2
# 14                       Marital_Status    object              3
# 15             Past_Disciplinary_Action    object              2
# 16  Previous_IntraDepartmental_Movement    object              2
# 17             No_of_previous_employers    object              7
# 18                      Promoted_or_Not     int64              2
#
#     Missing Values                               Sample Unique Values
# 0                0  [YAK/S/00001, YAK/S/00002, YAK/S/00003, YAK/S/...
# 1                0  [Commercial Sales and Marketing, Customer Supp...
# 2             1679  [MSc, MBA and PhD, First Degree or HND, nan, N...
# 3                0                                     [Female, Male]
# 4                0  [Direct Internal process, Agency and others, R...
# 5                0                                    [2, 3, 4, 5, 8]
# 6                0                     [1986, 1991, 1987, 1982, 1990]
# 7                0                        [12.5, 7.5, 2.5, 10.0, 0.0]
# 8                0                     [2011, 2015, 2012, 2009, 2014]
# 9                0                                             [1, 0]
# 10               0                                             [0, 1]
# 11               0                               [41, 52, 42, 77, 51]
# 12               0        [ANAMBRA, KATSINA, NIGER, AKWA IBOM, ENUGU]
# 13               0                                          [No, Yes]
# 14               0                        [Married, Single, Not_Sure]
# 15               0                                          [No, Yes]
# 16               0                                          [No, Yes]
# 17               0                                    [0, 1, 4, 3, 2]
# 18               0                                             [0, 1]

# %%
data.shape
# Out:
# (36633, 19)

# %%
data = data.dropna()

# %%
summarize_dataframe(data)
# Out:
#                                  Column Data Type  Unique Values  \
# 0                            EmployeeNo    object          36633
# 1                              Division    object              9
# 2                         Qualification    object              3
# 3                                Gender    object              2
# 4                Channel_of_Recruitment    object              3
# 5                    Trainings_Attended     int64             10
# 6                         Year_of_birth     int64             49
# 7                Last_performance_score   float64              6
# 8                   Year_of_recruitment     int64             35
# 9                           Targets_met     int64              2
# 10                       Previous_Award     int64              2
# 11               Training_score_average     int64             61
# 12                      State_Of_Origin    object             37
# 13                     Foreign_schooled    object              2
# 14                       Marital_Status    object              3
# 15             Past_Disciplinary_Action    object              2
# 16  Previous_IntraDepartmental_Movement    object              2
# 17             No_of_previous_employers    object              7
# 18                      Promoted_or_Not     int64              2
#
#     Missing Values                               Sample Unique Values
# 0                0  [YAK/S/00001, YAK/S/00002, YAK/S/00003, YAK/S/...
# 1                0  [Commercial Sales and Marketing, Customer Supp...
# 2                0  [MSc, MBA and PhD, First Degree or HND, Non-Un...
# 3                0                                     [Female, Male]
# 4                0  [Direct Internal process, Agency and others, R...
# 5                0                                    [2, 3, 5, 4, 8]
# 6                0                     [1986, 1991, 1987, 1982, 1990]
# 7                0                        [12.5, 7.5, 2.5, 10.0, 0.0]
# 8                0                     [2011, 2015, 2012, 2009, 2014]
# 9                0                                             [1, 0]
# 10               0                                             [0, 1]
# 11               0                               [41, 52, 42, 77, 51]
# 12               0        [ANAMBRA, KATSINA, NIGER, AKWA IBOM, ENUGU]
# 13               0                                          [No, Yes]
# 14               0                        [Married, Single, Not_Sure]
# 15               0                                          [No, Yes]
# 16               0                                          [No, Yes]
# 17               0                                    [0, 1, 4, 3, 2]
# 18               0                                             [0, 1]

# %%
data.columns.isnull()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False])

# %%
data.Year_of_recruitment.value_counts()
# Out:
# Year_of_recruitment
# 2016    4673
# 2015    4582
# 2017    4301
# 2014    3959
# 2012    3793
# 2013    3209
# 2018    2898
# 2011    1955
# 2010    1815
# 2009    1458
# 2008     600
# 2007     557
# 2006     456
# 2004     413
# 2003     385
# 2005     368
# 2002     288
# 2001     264
# 2000     224
# 1999      90
# 1998      51
# 1995      49
# 1996      43
# 1997      37
# 1994      34
# 1993      27
# 1990      22
# 1991      20
# 1992      20
# 1988      12
# 1989      11
# 1986       7
# 1987       7
# 1985       4
# 1982       1
# Name: count, dtype: int64

# %%
data.drop_duplicates()
# Out:
#         EmployeeNo                                     Division  \
# 0      YAK/S/00001               Commercial Sales and Marketing
# 1      YAK/S/00002        Customer Support and Field Operations
# 2      YAK/S/00003               Commercial Sales and Marketing
# 3      YAK/S/00004               Commercial Sales and Marketing
# 4      YAK/S/00006                     Information and Strategy
# ...            ...                                          ...
# 38306  YAK/S/54801                         People/HR Management
# 38307  YAK/S/54802  Information Technology and Solution Support
# 38308  YAK/S/54805        Customer Support and Field Operations
# 38309  YAK/S/54806                     Information and Strategy
# 38311  YAK/S/54808                         People/HR Management
#
#              Qualification  Gender   Channel_of_Recruitment  \
# 0         MSc, MBA and PhD  Female  Direct Internal process
# 1      First Degree or HND    Male        Agency and others
# 2      First Degree or HND    Male  Direct Internal process
# 3      First Degree or HND    Male        Agency and others
# 4      First Degree or HND    Male  Direct Internal process
# ...                    ...     ...                      ...
# 38306  First Degree or HND    Male        Agency and others
# 38307  First Degree or HND  Female  Direct Internal process
# 38308     MSc, MBA and PhD  Female        Agency and others
# 38309  First Degree or HND    Male        Agency and others
# 38311  First Degree or HND    Male        Agency and others
#
#        Trainings_Attended  Year_of_birth  Last_performance_score  \
# 0                       2           1986                    12.5
# 1                       2           1991                    12.5
# 2                       2           1987                     7.5
# 3                       3           1982                     2.5
# 4                       3           1990                     7.5
# ...                   ...            ...                     ...
# 38306                   3           1987                    12.5
# 38307                   2           1990                     0.0
# 38308                   2           1984                     5.0
# 38309                   2           1994                    12.5
# 38311                   2           1994                     2.5
#
#        Year_of_recruitment  Targets_met  Previous_Award  \
# 0                     2011            1               0
# 1                     2015            0               0
# 2                     2012            0               0
# 3                     2009            0               0
# 4                     2012            0               0
# ...                    ...          ...             ...
# 38306                 2016            0               0
# 38307                 2018            0               0
# 38308                 2013            0               0
# 38309                 2016            1               0
# 38311                 2014            0               0
#
#        Training_score_average State_Of_Origin Foreign_schooled Marital_Status  \
# 0                          41         ANAMBRA               No        Married
# 1                          52         ANAMBRA              Yes        Married
# 2                          42         KATSINA              Yes        Married
# 3                          42           NIGER              Yes         Single
# 4                          77       AKWA IBOM              Yes        Married
# ...                       ...             ...              ...            ...
# 38306                      44           LAGOS              Yes        Married
# 38307                      70           LAGOS              Yes        Married
# 38308                      48             IMO              Yes        Married
# 38309                      71         ANAMBRA               No        Married
# 38311                      41           KWARA              Yes         Single
#
#       Past_Disciplinary_Action Previous_IntraDepartmental_Movement  \
# 0                           No                                  No
# 1                           No                                  No
# 2                           No                                  No
# 3                           No                                  No
# 4                           No                                  No
# ...                        ...                                 ...
# 38306                       No                                  No
# 38307                       No                                  No
# 38308                       No                                  No
# 38309                       No                                  No
# 38311                       No                                  No
#
#       No_of_previous_employers  Promoted_or_Not
# 0                            0                0
# 1                            0                0
# 2                            0                0
# 3                            1                0
# 4                            1                0
# ...                        ...              ...
# 38306                        1                0
# 38307                        0                0
# 38308                        1                0
# 38309                        3                0
# 38311                        2                0
#
# [36633 rows x 19 columns]

# %%
#create the live_days column.
data['employee_age'] = (2024 - data['Year_of_recruitment'])

# %%
data = data.drop(columns=['Year_of_birth', 'EmployeeNo'])

# %%
data.to_csv('../data/interim/promotion/train_clean2.csv', index=False)

# %%
data.describe()
# Out:
#        Trainings_Attended  Last_performance_score  Year_of_recruitment  \
# count        36633.000000            36633.000000         36633.000000
# mean             2.255944                7.746704          2013.073786
# std              0.612757                3.717976             4.270863
# min              2.000000                0.000000          1982.000000
# 25%              2.000000                5.000000          2011.000000
# 50%              2.000000                7.500000          2014.000000
# 75%              2.000000               10.000000          2016.000000
# max             11.000000               12.500000          2018.000000
#
#         Targets_met  Previous_Award  Training_score_average  Promoted_or_Not  \
# count  36633.000000    36633.000000            36633.000000     36633.000000
# mean       0.357874        0.023203               55.616957         0.086234
# std        0.479381        0.150550               13.295068         0.280713
# min        0.000000        0.000000               31.000000         0.000000
# 25%        0.000000        0.000000               43.000000         0.000000
# 50%        0.000000        0.000000               52.000000         0.000000
# 75%        1.000000        0.000000               68.000000         0.000000
# max        1.000000        1.000000               91.000000         1.000000
#
#        employee_age
# count  36633.000000
# mean      10.926214
# std        4.270863
# min        6.000000
# 25%        8.000000
# 50%       10.000000
# 75%       13.000000
# max       42.000000

# %% [markdown]
# # Data Changes to be done:
# - Change year to employee_age in the company
# - Check ID for more information

# %% [markdown]
# ## Helpful Actions

# %%
pct = np.percentile(data.loc[:, 'search_views'].fillna(np.mean(data.loc[:, 'search_views'])), 95)
print(pct)
print(data.shape)
data = data.loc[data.loc[:, 'search_views'] < pct]
print(data.shape)

# %%
#convert created_date and deleted_date to datetime.
data[['created_date','deleted_date']] = data[['created_date','deleted_date']].apply(
    lambda _: pd.to_datetime(_))

#create the live_days column.
data['live_days'] = (data['deleted_date'] - data['created_date']).dt.days

# %%
#drop all cars with first_registration_year of more than 2022
data = data[data['first_registration_year'] <= 2024]

#drop all columns with negative live days. (since you cannot have a listing deleted before it is created)
data = data[data['live_days'] >= 0]

#drop all negative stock days
data = data[data['stock_days'] >= 0]

#drop all cars with price less than 100 euros
data = data[data.price > 100]

# %%
columns_to_drop = ['deleted_date', 'created_date', 'first_registration_year', 'article_id', 'ctr']
data = data.drop(columns=columns_to_drop)
